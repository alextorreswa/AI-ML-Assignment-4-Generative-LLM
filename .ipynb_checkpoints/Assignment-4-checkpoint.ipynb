# %%
# !pip install transformers torch --upgrade
# Out:
# ...
# WARNING: Error parsing dependencies of pyodbc: Invalid version: '4.0.0-unsupported'
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Alex\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 107, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\Alex\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 98, in _inner_run
#     return self.run(options, args)
#   File "C:\Users\Alex\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 85, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Alex\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 484, in run
#     installed_versions[distribution.canonical_name] = distribution.version
#   File "C:\Users\Alex\anaconda3\lib\site-packages\pip\_internal\metadata\pkg_resources.py", line 189, in version
#     return parse_version(self._dist.version)
# ...
